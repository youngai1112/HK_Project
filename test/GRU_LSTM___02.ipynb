# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
def Nomalizaion_datas(df):
        # 훈련시킬 데이터와, 학습후 결과를 확인할 데이터 분리
    df = df.loc[df['Date']<="2021"]
    df.sort_index(ascending=False).reset_index(drop=True)

    #정규화하기
    scaler = MinMaxScaler()
    scale_cols = ['시가', '고가', '저가', '현재가', '거래량', '거래대금', 'D', 'G',
        'O', 'Dow', 'kosdaq', 'nasdaq', 'S&P500']
    df_scaled = scaler.fit_transform(df[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    
    # 테스트사이즈, 윈도우사이즈 설정
    TEST_SIZE = 200
    WINDOW_SIZE = 20

    #--------------------------------------------------------
    train = df_scaled[:-TEST_SIZE]
    test = df_scaled[-TEST_SIZE:]

    test.reset_index(drop=True, inplace=True)
    
    return  train, test


def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(label_list)


 
def training_target(train):
    
    feature_cols = ['시가', '고가', '저가', '거래량', '거래대금', 'D', 'G',
            'O', 'kosdaq']
    label_cols = ['현재가']

    train_feature = train[feature_cols]
    train_label = train[label_cols]

    train_feature, train_label = make_dataset(train_feature, train_label, 20)

    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
    
    return x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label

  
def test_feature_label(feature_cols, label_cols):
    test_feature = test[feature_cols]
    test_label = test[label_cols]

    X_test, y_test = make_dataset(test_feature, test_label, 20)
    
    return X_test, y_test, test_feature, test_label

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM , Conv1D, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 모델 생성

# %%
df = pd.read_excel("data_kosdaq_price_OGD/월덱스.xlsx.xlsx")
train, test= Nomalizaion_datas(df)
x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label = training_target(train)
X_test, y_test, test_feature, test_label = test_feature_label(feature_cols, label_cols)

# %%
  model = Sequential()
  model.add(GRU(units = 64, 
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 160,
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 160,  
             activation='relu', 
             return_sequences=True))
  model.add(LSTM(units = 384, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='relu',))
  optimizer_2 = Adam(0.0003)
  model.compile(loss='mean_squared_error', optimizer=optimizer_2, metrics=["accuracy"])
  early_stop = EarlyStopping(monitor='val_loss', patience=30)

# %%
model_path = 'model'
filename = os.path.join(model_path, '월덱스_02.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train, epochs=50, batch_size=32, shuffle=False, callbacks=[early_stop, checkpoint], validation_data=(x_valid, y_valid))
    model.save('월덱스_02.h5')
    model.reset_states()
# Out:
# Epoch 1/50
# 69/69 [==============================] - 10s 122ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 7.3223e-04 - val_accuracy: 0.0018
#
# Epoch 00001: val_loss improved from inf to 0.00073, saving model to model/월덱스_02.h5
# Epoch 2/50
# 69/69 [==============================] - 8s 114ms/step - loss: 8.3045e-04 - accuracy: 0.0000e+00 - val_loss: 6.0473e-04 - val_accuracy: 0.0018
#
# Epoch 00002: val_loss improved from 0.00073 to 0.00060, saving model to model/월덱스_02.h5
# Epoch 3/50
# 69/69 [==============================] - 8s 122ms/step - loss: 7.7500e-04 - accuracy: 0.0000e+00 - val_loss: 5.4125e-04 - val_accuracy: 0.0018
#
# Epoch 00003: val_loss improved from 0.00060 to 0.00054, saving model to model/월덱스_02.h5
# Epoch 4/50
# 69/69 [==============================] - 8s 120ms/step - loss: 7.1131e-04 - accuracy: 0.0000e+00 - val_loss: 5.0625e-04 - val_accuracy: 0.0018
#
# Epoch 00004: val_loss improved from 0.00054 to 0.00051, saving model to model/월덱스_02.h5
# Epoch 5/50
# 69/69 [==============================] - 8s 118ms/step - loss: 7.3753e-04 - accuracy: 0.0000e+00 - val_loss: 4.7658e-04 - val_accuracy: 0.0018
#
# Epoch 00005: val_loss improved from 0.00051 to 0.00048, saving model to model/월덱스_02.h5
# Epoch 6/50
# 69/69 [==============================] - 9s 126ms/step - loss: 6.9366e-04 - accuracy: 0.0000e+00 - val_loss: 4.5024e-04 - val_accuracy: 0.0018
#
# Epoch 00006: val_loss improved from 0.00048 to 0.00045, saving model to model/월덱스_02.h5
# Epoch 7/50
# 69/69 [==============================] - 7s 108ms/step - loss: 6.4464e-04 - accuracy: 0.0000e+00 - val_loss: 4.3510e-04 - val_accuracy: 0.0018
#
# Epoch 00007: val_loss improved from 0.00045 to 0.00044, saving model to model/월덱스_02.h5
# Epoch 8/50
# 69/69 [==============================] - 7s 103ms/step - loss: 6.1858e-04 - accuracy: 0.0000e+00 - val_loss: 4.1797e-04 - val_accuracy: 0.0018
#
# Epoch 00008: val_loss improved from 0.00044 to 0.00042, saving model to model/월덱스_02.h5
# Epoch 9/50
# 69/69 [==============================] - 7s 105ms/step - loss: 5.5883e-04 - accuracy: 0.0000e+00 - val_loss: 3.7848e-04 - val_accuracy: 0.0018
#
# Epoch 00009: val_loss improved from 0.00042 to 0.00038, saving model to model/월덱스_02.h5
# Epoch 10/50
# 69/69 [==============================] - 7s 100ms/step - loss: 5.8388e-04 - accuracy: 0.0000e+00 - val_loss: 3.8622e-04 - val_accuracy: 0.0018
#
# Epoch 00010: val_loss did not improve from 0.00038
# Epoch 11/50
# 69/69 [==============================] - 7s 102ms/step - loss: 5.8099e-04 - accuracy: 0.0000e+00 - val_loss: 3.5299e-04 - val_accuracy: 0.0018
#
# Epoch 00011: val_loss improved from 0.00038 to 0.00035, saving model to model/월덱스_02.h5
# Epoch 12/50
# 69/69 [==============================] - 8s 109ms/step - loss: 5.2358e-04 - accuracy: 0.0000e+00 - val_loss: 3.6071e-04 - val_accuracy: 0.0018
#
# Epoch 00012: val_loss did not improve from 0.00035
# Epoch 13/50
# 69/69 [==============================] - 7s 108ms/step - loss: 5.1042e-04 - accuracy: 0.0000e+00 - val_loss: 4.1513e-04 - val_accuracy: 0.0018
#
# Epoch 00013: val_loss did not improve from 0.00035
# Epoch 14/50
# 69/69 [==============================] - 8s 111ms/step - loss: 5.1601e-04 - accuracy: 0.0000e+00 - val_loss: 3.1161e-04 - val_accuracy: 0.0018
#
# Epoch 00014: val_loss improved from 0.00035 to 0.00031, saving model to model/월덱스_02.h5
# Epoch 15/50
# 69/69 [==============================] - 7s 99ms/step - loss: 5.4383e-04 - accuracy: 0.0000e+00 - val_loss: 3.1270e-04 - val_accuracy: 0.0018
#
# Epoch 00015: val_loss did not improve from 0.00031
# Epoch 16/50
# 69/69 [==============================] - 6s 88ms/step - loss: 5.1325e-04 - accuracy: 0.0000e+00 - val_loss: 2.9048e-04 - val_accuracy: 0.0018
#
# Epoch 00016: val_loss improved from 0.00031 to 0.00029, saving model to model/월덱스_02.h5
# Epoch 17/50
# 69/69 [==============================] - 6s 90ms/step - loss: 4.4892e-04 - accuracy: 0.0000e+00 - val_loss: 3.9351e-04 - val_accuracy: 0.0018
#
# Epoch 00017: val_loss did not improve from 0.00029
# Epoch 18/50
# 69/69 [==============================] - 8s 112ms/step - loss: 4.1543e-04 - accuracy: 0.0000e+00 - val_loss: 3.1844e-04 - val_accuracy: 0.0018
#
# Epoch 00018: val_loss did not improve from 0.00029
# Epoch 19/50
# 69/69 [==============================] - 8s 121ms/step - loss: 4.2160e-04 - accuracy: 0.0000e+00 - val_loss: 2.8242e-04 - val_accuracy: 0.0018
#
# Epoch 00019: val_loss improved from 0.00029 to 0.00028, saving model to model/월덱스_02.h5
# Epoch 20/50
# 69/69 [==============================] - 8s 117ms/step - loss: 4.0588e-04 - accuracy: 0.0000e+00 - val_loss: 2.5727e-04 - val_accuracy: 0.0018
#
# Epoch 00020: val_loss improved from 0.00028 to 0.00026, saving model to model/월덱스_02.h5
# Epoch 21/50
# 69/69 [==============================] - 9s 126ms/step - loss: 4.0321e-04 - accuracy: 0.0000e+00 - val_loss: 2.4195e-04 - val_accuracy: 0.0018
#
# Epoch 00021: val_loss improved from 0.00026 to 0.00024, saving model to model/월덱스_02.h5
# Epoch 22/50
# 69/69 [==============================] - 8s 116ms/step - loss: 3.8710e-04 - accuracy: 0.0000e+00 - val_loss: 2.4114e-04 - val_accuracy: 0.0018
#
# Epoch 00022: val_loss improved from 0.00024 to 0.00024, saving model to model/월덱스_02.h5
# Epoch 23/50
# 69/69 [==============================] - 9s 126ms/step - loss: 3.7200e-04 - accuracy: 0.0000e+00 - val_loss: 2.2797e-04 - val_accuracy: 0.0018
#
# Epoch 00023: val_loss improved from 0.00024 to 0.00023, saving model to model/월덱스_02.h5
# Epoch 24/50
# 69/69 [==============================] - 7s 98ms/step - loss: 3.6857e-04 - accuracy: 0.0000e+00 - val_loss: 4.6509e-04 - val_accuracy: 0.0018
#
# Epoch 00024: val_loss did not improve from 0.00023
# Epoch 25/50
# 69/69 [==============================] - 7s 103ms/step - loss: 3.7708e-04 - accuracy: 0.0000e+00 - val_loss: 3.0810e-04 - val_accuracy: 0.0018
#
# Epoch 00025: val_loss did not improve from 0.00023
# Epoch 26/50
# 69/69 [==============================] - 8s 115ms/step - loss: 3.5652e-04 - accuracy: 0.0000e+00 - val_loss: 2.1700e-04 - val_accuracy: 0.0018
#
# Epoch 00026: val_loss improved from 0.00023 to 0.00022, saving model to model/월덱스_02.h5
# Epoch 27/50
# 69/69 [==============================] - 8s 117ms/step - loss: 3.6056e-04 - accuracy: 0.0000e+00 - val_loss: 2.1544e-04 - val_accuracy: 0.0018
#
# Epoch 00027: val_loss improved from 0.00022 to 0.00022, saving model to model/월덱스_02.h5
# Epoch 28/50
# 69/69 [==============================] - 8s 113ms/step - loss: 3.5634e-04 - accuracy: 0.0000e+00 - val_loss: 3.1548e-04 - val_accuracy: 0.0018
#
# Epoch 00028: val_loss did not improve from 0.00022
# Epoch 29/50
# 69/69 [==============================] - 7s 103ms/step - loss: 3.4341e-04 - accuracy: 0.0000e+00 - val_loss: 2.5389e-04 - val_accuracy: 0.0018
#
# Epoch 00029: val_loss did not improve from 0.00022
# Epoch 30/50
# 69/69 [==============================] - 8s 112ms/step - loss: 3.3274e-04 - accuracy: 0.0000e+00 - val_loss: 2.5414e-04 - val_accuracy: 0.0018
#
# Epoch 00030: val_loss did not improve from 0.00022
# Epoch 31/50
# 69/69 [==============================] - 8s 115ms/step - loss: 3.1772e-04 - accuracy: 0.0000e+00 - val_loss: 1.9234e-04 - val_accuracy: 0.0018
#
# Epoch 00031: val_loss improved from 0.00022 to 0.00019, saving model to model/월덱스_02.h5
# Epoch 32/50
# 69/69 [==============================] - 8s 118ms/step - loss: 3.2267e-04 - accuracy: 0.0000e+00 - val_loss: 2.0368e-04 - val_accuracy: 0.0018
#
# Epoch 00032: val_loss did not improve from 0.00019
# Epoch 33/50
# 69/69 [==============================] - 8s 116ms/step - loss: 3.1213e-04 - accuracy: 0.0000e+00 - val_loss: 2.2851e-04 - val_accuracy: 0.0018
#
# Epoch 00033: val_loss did not improve from 0.00019
# Epoch 34/50
# 69/69 [==============================] - 8s 112ms/step - loss: 3.1529e-04 - accuracy: 0.0000e+00 - val_loss: 2.0110e-04 - val_accuracy: 0.0018
#
# Epoch 00034: val_loss did not improve from 0.00019
# Epoch 35/50
# 69/69 [==============================] - 8s 122ms/step - loss: 3.0068e-04 - accuracy: 0.0000e+00 - val_loss: 1.6596e-04 - val_accuracy: 0.0018
#
# Epoch 00035: val_loss improved from 0.00019 to 0.00017, saving model to model/월덱스_02.h5
# Epoch 36/50
# 69/69 [==============================] - 6s 94ms/step - loss: 2.9812e-04 - accuracy: 0.0000e+00 - val_loss: 1.7746e-04 - val_accuracy: 0.0018
#
# Epoch 00036: val_loss did not improve from 0.00017
# Epoch 37/50
# 69/69 [==============================] - 6s 91ms/step - loss: 2.9391e-04 - accuracy: 0.0000e+00 - val_loss: 1.8749e-04 - val_accuracy: 0.0018
#
# Epoch 00037: val_loss did not improve from 0.00017
# Epoch 38/50
# 69/69 [==============================] - 6s 90ms/step - loss: 2.8570e-04 - accuracy: 0.0000e+00 - val_loss: 1.6960e-04 - val_accuracy: 0.0018
#
# Epoch 00038: val_loss did not improve from 0.00017
# Epoch 39/50
# 69/69 [==============================] - 8s 114ms/step - loss: 2.9555e-04 - accuracy: 0.0000e+00 - val_loss: 1.7946e-04 - val_accuracy: 0.0018
#
# Epoch 00039: val_loss did not improve from 0.00017
# Epoch 40/50
# 69/69 [==============================] - 8s 115ms/step - loss: 2.8059e-04 - accuracy: 0.0000e+00 - val_loss: 1.9857e-04 - val_accuracy: 0.0018
#
# Epoch 00040: val_loss did not improve from 0.00017
# Epoch 41/50
# 69/69 [==============================] - 8s 123ms/step - loss: 3.1014e-04 - accuracy: 0.0000e+00 - val_loss: 2.1810e-04 - val_accuracy: 0.0018
#
# Epoch 00041: val_loss did not improve from 0.00017
# Epoch 42/50
# 69/69 [==============================] - 9s 125ms/step - loss: 2.7451e-04 - accuracy: 0.0000e+00 - val_loss: 1.7837e-04 - val_accuracy: 0.0018
#
# Epoch 00042: val_loss did not improve from 0.00017
# Epoch 43/50
# 69/69 [==============================] - 8s 114ms/step - loss: 2.5548e-04 - accuracy: 0.0000e+00 - val_loss: 1.6321e-04 - val_accuracy: 0.0018
#
# Epoch 00043: val_loss improved from 0.00017 to 0.00016, saving model to model/월덱스_02.h5
# Epoch 44/50
# 69/69 [==============================] - 6s 90ms/step - loss: 2.6150e-04 - accuracy: 0.0000e+00 - val_loss: 1.5479e-04 - val_accuracy: 0.0018
#
# Epoch 00044: val_loss improved from 0.00016 to 0.00015, saving model to model/월덱스_02.h5
# Epoch 45/50
# 69/69 [==============================] - 6s 90ms/step - loss: 2.6948e-04 - accuracy: 0.0000e+00 - val_loss: 2.0170e-04 - val_accuracy: 0.0018
#
# Epoch 00045: val_loss did not improve from 0.00015
# Epoch 46/50
# 69/69 [==============================] - 6s 90ms/step - loss: 2.5709e-04 - accuracy: 0.0000e+00 - val_loss: 1.6039e-04 - val_accuracy: 0.0018
#
# Epoch 00046: val_loss did not improve from 0.00015
# Epoch 47/50
# 69/69 [==============================] - 6s 93ms/step - loss: 2.6603e-04 - accuracy: 0.0000e+00 - val_loss: 1.4444e-04 - val_accuracy: 0.0018
#
# Epoch 00047: val_loss improved from 0.00015 to 0.00014, saving model to model/월덱스_02.h5
# Epoch 48/50
# 69/69 [==============================] - 6s 94ms/step - loss: 2.6679e-04 - accuracy: 0.0000e+00 - val_loss: 1.8766e-04 - val_accuracy: 0.0018
#
# Epoch 00048: val_loss did not improve from 0.00014
# Epoch 49/50
# 69/69 [==============================] - 6s 91ms/step - loss: 2.5781e-04 - accuracy: 0.0000e+00 - val_loss: 1.4232e-04 - val_accuracy: 0.0018
#
# Epoch 00049: val_loss improved from 0.00014 to 0.00014, saving model to model/월덱스_02.h5
# Epoch 50/50
# 69/69 [==============================] - 6s 90ms/step - loss: 2.4763e-04 - accuracy: 0.0000e+00 - val_loss: 1.4752e-04 - val_accuracy: 0.0018
#
# Epoch 00050: val_loss did not improve from 0.00014

# %%
model.load_weights(filename)
pred = model.predict(X_test)
plt.figure(figsize=(12, 9))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.006786195918065589, 0.8307045677681246)

# %%
X_test.shape
# Out:
# (180, 20, 9)

# %%
def min_max_scaling(ori_column):
      ori_column_np = np.asarray(ori_column)
      
      return (ori_column_np - ori_column_np.min()) / (ori_column_np.max() - ori_column_np.min()) + 1e-12

# %%
# def inverse_scaling(ori_column, column):
#     ori_column_np = np.asarray(ori_column)
#     column_np = np.asarray(column)

#     return (column_np * (ori_column_np.max() - ori_column_np.min() + 1e-12)) + ori_column_np.min()

# %%
def inverse_scaling(ori_column):
    ori_column_np = np.asarray(ori_column)

    return ((ori_column_np.max() - ori_column_np.min() + 1e-12)) + ori_column_np.min()

# %%
pred_ori = inverse_scaling(X_test)
pred_ori
# Out:
# 1.000000000001
