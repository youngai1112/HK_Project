# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
def Nomalizaion_datas(df):
        # 훈련시킬 데이터와, 학습후 결과를 확인할 데이터 분리
    df = df.loc[df['Date']<="2021"]
    df.sort_index(ascending=False).reset_index(drop=True)

    #정규화하기
    scaler = MinMaxScaler()
    scale_cols = ['시가', '고가', '저가', '현재가', '거래량', '거래대금', 'D', 'G',
        'O', 'Dow', 'kosdaq', 'nasdaq', 'S&P500']
    df_scaled = scaler.fit_transform(df[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    
    # 테스트사이즈, 윈도우사이즈 설정
    TEST_SIZE = 200
    WINDOW_SIZE = 20

    #--------------------------------------------------------
    train = df_scaled[:-TEST_SIZE]
    test = df_scaled[-TEST_SIZE:]

    test.reset_index(drop=True, inplace=True)
    
    return  train, test


def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(label_list)


 
def training_target(train):
    
    feature_cols = ['시가', '고가', '저가', '거래량', '거래대금', 'D', 'G',
            'O', 'kosdaq']
    label_cols = ['현재가']

    train_feature = train[feature_cols]
    train_label = train[label_cols]

    train_feature, train_label = make_dataset(train_feature, train_label, 20)

    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
    
    return x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label

  
def test_feature_label(feature_cols, label_cols):
    test_feature = test[feature_cols]
    test_label = test[label_cols]

    X_test, y_test = make_dataset(test_feature, test_label, 20)
    
    return X_test, y_test, test_feature, test_label

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM , Conv1D, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 모델 생성

# %%
df = pd.read_excel("data_kosdaq_price_OGD/코세스.xlsx.xlsx")
train, test= Nomalizaion_datas(df)
x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label = training_target(train)
X_test, y_test, test_feature, test_label = test_feature_label(feature_cols, label_cols)

# %%
  model = Sequential()
  model.add(GRU(units = 480, 
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 384,
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 224,  
             activation='relu', 
             return_sequences=True))
  model.add(LSTM(units = 480, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='relu',))
  optimizer_2 = Adam(0.005)
  model.compile(loss='mean_squared_error', optimizer=optimizer_2, metrics=["accuracy"])
  early_stop = EarlyStopping(monitor='val_loss', patience=30)
# Out:
# 2022-03-28 11:11:44.484292: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_path = 'model'
filename = os.path.join(model_path, '코세스.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train, epochs=50, batch_size=32, shuffle=False, callbacks=[early_stop, checkpoint], validation_data=(x_valid, y_valid))
    model.save('코세스.h5')
    model.reset_states()
# Out:
# Epoch 1/50
# 79/79 [==============================] - 23s 294ms/step - loss: 0.0017 - accuracy: 7.9745e-04 - val_loss: 7.6040e-04 - val_accuracy: 0.0016
#
# Epoch 00001: val_loss improved from inf to 0.00076, saving model to model/코세스.h5
# Epoch 2/50
# 79/79 [==============================] - 23s 287ms/step - loss: 0.0014 - accuracy: 7.9745e-04 - val_loss: 6.3444e-04 - val_accuracy: 0.0016
#
# Epoch 00002: val_loss improved from 0.00076 to 0.00063, saving model to model/코세스.h5
# Epoch 3/50
# 79/79 [==============================] - 23s 287ms/step - loss: 0.0015 - accuracy: 7.9745e-04 - val_loss: 0.0019 - val_accuracy: 0.0016
#
# Epoch 00003: val_loss did not improve from 0.00063
# Epoch 4/50
# 79/79 [==============================] - 23s 294ms/step - loss: 0.0013 - accuracy: 7.9745e-04 - val_loss: 0.0021 - val_accuracy: 0.0016
#
# Epoch 00004: val_loss did not improve from 0.00063
# Epoch 5/50
# 79/79 [==============================] - 22s 284ms/step - loss: 0.0013 - accuracy: 7.9745e-04 - val_loss: 9.0234e-04 - val_accuracy: 0.0016
#
# Epoch 00005: val_loss did not improve from 0.00063
# Epoch 6/50
# 79/79 [==============================] - 21s 269ms/step - loss: 0.0011 - accuracy: 7.9745e-04 - val_loss: 0.0019 - val_accuracy: 0.0016
#
# Epoch 00006: val_loss did not improve from 0.00063
# Epoch 7/50
# 79/79 [==============================] - 22s 275ms/step - loss: 0.0010 - accuracy: 7.9745e-04 - val_loss: 8.7373e-04 - val_accuracy: 0.0016
#
# Epoch 00007: val_loss did not improve from 0.00063
# Epoch 8/50
# 79/79 [==============================] - 22s 277ms/step - loss: 8.7310e-04 - accuracy: 7.9745e-04 - val_loss: 0.0014 - val_accuracy: 0.0016
#
# Epoch 00008: val_loss did not improve from 0.00063
# Epoch 9/50
# 79/79 [==============================] - 22s 279ms/step - loss: 9.0303e-04 - accuracy: 7.9745e-04 - val_loss: 3.8342e-04 - val_accuracy: 0.0016
#
# Epoch 00009: val_loss improved from 0.00063 to 0.00038, saving model to model/코세스.h5
# Epoch 10/50
# 79/79 [==============================] - 23s 296ms/step - loss: 7.5909e-04 - accuracy: 7.9745e-04 - val_loss: 6.7598e-04 - val_accuracy: 0.0016
#
# Epoch 00010: val_loss did not improve from 0.00038
# Epoch 11/50
# 79/79 [==============================] - 22s 273ms/step - loss: 7.7869e-04 - accuracy: 7.9745e-04 - val_loss: 8.0946e-04 - val_accuracy: 0.0016
#
# Epoch 00011: val_loss did not improve from 0.00038
# Epoch 12/50
# 79/79 [==============================] - 21s 268ms/step - loss: 7.8254e-04 - accuracy: 7.9745e-04 - val_loss: 0.0014 - val_accuracy: 0.0016
#
# Epoch 00012: val_loss did not improve from 0.00038
# Epoch 13/50
# 79/79 [==============================] - 23s 290ms/step - loss: 7.9857e-04 - accuracy: 7.9745e-04 - val_loss: 3.1750e-04 - val_accuracy: 0.0016
#
# Epoch 00013: val_loss improved from 0.00038 to 0.00032, saving model to model/코세스.h5
# Epoch 14/50
# 79/79 [==============================] - 23s 293ms/step - loss: 8.2030e-04 - accuracy: 7.9745e-04 - val_loss: 4.9830e-04 - val_accuracy: 0.0016
#
# Epoch 00014: val_loss did not improve from 0.00032
# Epoch 15/50
# 79/79 [==============================] - 21s 271ms/step - loss: 7.5348e-04 - accuracy: 7.9745e-04 - val_loss: 9.2388e-04 - val_accuracy: 0.0016
#
# Epoch 00015: val_loss did not improve from 0.00032
# Epoch 16/50
# 79/79 [==============================] - 23s 292ms/step - loss: 7.2247e-04 - accuracy: 7.9745e-04 - val_loss: 2.3668e-04 - val_accuracy: 0.0016
#
# Epoch 00016: val_loss improved from 0.00032 to 0.00024, saving model to model/코세스.h5
# Epoch 17/50
# 79/79 [==============================] - 22s 285ms/step - loss: 7.0919e-04 - accuracy: 7.9745e-04 - val_loss: 8.7272e-04 - val_accuracy: 0.0016
#
# Epoch 00017: val_loss did not improve from 0.00024
# Epoch 18/50
# 79/79 [==============================] - 22s 284ms/step - loss: 7.0338e-04 - accuracy: 7.9745e-04 - val_loss: 5.9545e-04 - val_accuracy: 0.0016
#
# Epoch 00018: val_loss did not improve from 0.00024
# Epoch 19/50
# 79/79 [==============================] - 24s 297ms/step - loss: 7.4248e-04 - accuracy: 7.9745e-04 - val_loss: 6.5677e-04 - val_accuracy: 0.0016
#
# Epoch 00019: val_loss did not improve from 0.00024
# Epoch 20/50
# 79/79 [==============================] - 21s 267ms/step - loss: 5.5556e-04 - accuracy: 7.9745e-04 - val_loss: 1.7395e-04 - val_accuracy: 0.0016
#
# Epoch 00020: val_loss improved from 0.00024 to 0.00017, saving model to model/코세스.h5
# Epoch 21/50
# 79/79 [==============================] - 22s 275ms/step - loss: 5.9697e-04 - accuracy: 7.9745e-04 - val_loss: 5.1293e-04 - val_accuracy: 0.0016
#
# Epoch 00021: val_loss did not improve from 0.00017
# Epoch 22/50
# 79/79 [==============================] - 22s 274ms/step - loss: 6.2411e-04 - accuracy: 7.9745e-04 - val_loss: 3.2932e-04 - val_accuracy: 0.0016
#
# Epoch 00022: val_loss did not improve from 0.00017
# Epoch 23/50
# 79/79 [==============================] - 22s 275ms/step - loss: 5.6612e-04 - accuracy: 7.9745e-04 - val_loss: 5.6344e-04 - val_accuracy: 0.0016
#
# Epoch 00023: val_loss did not improve from 0.00017
# Epoch 24/50
# 79/79 [==============================] - 22s 272ms/step - loss: 5.1439e-04 - accuracy: 7.9745e-04 - val_loss: 2.4528e-04 - val_accuracy: 0.0016
#
# Epoch 00024: val_loss did not improve from 0.00017
# Epoch 25/50
# 79/79 [==============================] - 22s 277ms/step - loss: 5.8373e-04 - accuracy: 7.9745e-04 - val_loss: 1.9115e-04 - val_accuracy: 0.0016
#
# Epoch 00025: val_loss did not improve from 0.00017
# Epoch 26/50
# 79/79 [==============================] - 23s 290ms/step - loss: 5.8791e-04 - accuracy: 7.9745e-04 - val_loss: 0.0011 - val_accuracy: 0.0016
#
# Epoch 00026: val_loss did not improve from 0.00017
# Epoch 27/50
# 79/79 [==============================] - 23s 289ms/step - loss: 5.8533e-04 - accuracy: 7.9745e-04 - val_loss: 7.0927e-04 - val_accuracy: 0.0016
#
# Epoch 00027: val_loss did not improve from 0.00017
# Epoch 28/50
# 79/79 [==============================] - 19s 245ms/step - loss: 5.9206e-04 - accuracy: 7.9745e-04 - val_loss: 7.0186e-04 - val_accuracy: 0.0016
#
# Epoch 00028: val_loss did not improve from 0.00017
# Epoch 29/50
# 79/79 [==============================] - 21s 265ms/step - loss: 6.2517e-04 - accuracy: 7.9745e-04 - val_loss: 2.4493e-04 - val_accuracy: 0.0016
#
# Epoch 00029: val_loss did not improve from 0.00017
# Epoch 30/50
# 79/79 [==============================] - 23s 288ms/step - loss: 5.9197e-04 - accuracy: 7.9745e-04 - val_loss: 6.1979e-04 - val_accuracy: 0.0016
#
# Epoch 00030: val_loss did not improve from 0.00017
# Epoch 31/50
# 79/79 [==============================] - 23s 286ms/step - loss: 7.1352e-04 - accuracy: 7.9745e-04 - val_loss: 6.0402e-04 - val_accuracy: 0.0016
#
# Epoch 00031: val_loss did not improve from 0.00017
# Epoch 32/50
# 79/79 [==============================] - 21s 267ms/step - loss: 5.6224e-04 - accuracy: 7.9745e-04 - val_loss: 7.9520e-04 - val_accuracy: 0.0016
#
# Epoch 00032: val_loss did not improve from 0.00017
# Epoch 33/50
# 79/79 [==============================] - 22s 276ms/step - loss: 6.3326e-04 - accuracy: 7.9745e-04 - val_loss: 2.6103e-04 - val_accuracy: 0.0016
#
# Epoch 00033: val_loss did not improve from 0.00017
# Epoch 34/50
# 79/79 [==============================] - 21s 271ms/step - loss: 6.0673e-04 - accuracy: 7.9745e-04 - val_loss: 6.3924e-04 - val_accuracy: 0.0016
#
# Epoch 00034: val_loss did not improve from 0.00017
# Epoch 35/50
# 79/79 [==============================] - 22s 277ms/step - loss: 5.4881e-04 - accuracy: 7.9745e-04 - val_loss: 4.2801e-04 - val_accuracy: 0.0016
#
# Epoch 00035: val_loss did not improve from 0.00017
# Epoch 36/50
# 79/79 [==============================] - 21s 267ms/step - loss: 5.5763e-04 - accuracy: 7.9745e-04 - val_loss: 4.8660e-04 - val_accuracy: 0.0016
#
# Epoch 00036: val_loss did not improve from 0.00017
# Epoch 37/50
# 79/79 [==============================] - 19s 239ms/step - loss: 5.2105e-04 - accuracy: 7.9745e-04 - val_loss: 6.2066e-04 - val_accuracy: 0.0016
#
# Epoch 00037: val_loss did not improve from 0.00017
# Epoch 38/50
# 79/79 [==============================] - 18s 232ms/step - loss: 6.7362e-04 - accuracy: 7.9745e-04 - val_loss: 3.4806e-04 - val_accuracy: 0.0016
#
# Epoch 00038: val_loss did not improve from 0.00017
# Epoch 39/50
# 79/79 [==============================] - 19s 238ms/step - loss: 4.8227e-04 - accuracy: 7.9745e-04 - val_loss: 3.4505e-04 - val_accuracy: 0.0016
#
# Epoch 00039: val_loss did not improve from 0.00017
# Epoch 40/50
# 79/79 [==============================] - 21s 264ms/step - loss: 5.6344e-04 - accuracy: 7.9745e-04 - val_loss: 3.4799e-04 - val_accuracy: 0.0016
#
# Epoch 00040: val_loss did not improve from 0.00017
# Epoch 41/50
# 79/79 [==============================] - 22s 274ms/step - loss: 7.0883e-04 - accuracy: 7.9745e-04 - val_loss: 4.9326e-04 - val_accuracy: 0.0016
#
# Epoch 00041: val_loss did not improve from 0.00017
# Epoch 42/50
# 79/79 [==============================] - 22s 276ms/step - loss: 6.2264e-04 - accuracy: 7.9745e-04 - val_loss: 5.2260e-04 - val_accuracy: 0.0016
#
# Epoch 00042: val_loss did not improve from 0.00017
# Epoch 43/50
# 79/79 [==============================] - 22s 279ms/step - loss: 5.7873e-04 - accuracy: 7.9745e-04 - val_loss: 5.7953e-04 - val_accuracy: 0.0016
#
# Epoch 00043: val_loss did not improve from 0.00017
# Epoch 44/50
# 79/79 [==============================] - 20s 254ms/step - loss: 5.5986e-04 - accuracy: 7.9745e-04 - val_loss: 3.8024e-04 - val_accuracy: 0.0016
#
# Epoch 00044: val_loss did not improve from 0.00017
# Epoch 45/50
# 79/79 [==============================] - 20s 250ms/step - loss: 4.9289e-04 - accuracy: 7.9745e-04 - val_loss: 2.2165e-04 - val_accuracy: 0.0016
#
# Epoch 00045: val_loss did not improve from 0.00017
# Epoch 46/50
# 79/79 [==============================] - 19s 240ms/step - loss: 6.1424e-04 - accuracy: 7.9745e-04 - val_loss: 2.4381e-04 - val_accuracy: 0.0016
#
# Epoch 00046: val_loss did not improve from 0.00017
# Epoch 47/50
# 79/79 [==============================] - 21s 263ms/step - loss: 5.2534e-04 - accuracy: 7.9745e-04 - val_loss: 3.6524e-04 - val_accuracy: 0.0016
#
# Epoch 00047: val_loss did not improve from 0.00017
# Epoch 48/50
# 79/79 [==============================] - 22s 285ms/step - loss: 4.9671e-04 - accuracy: 7.9745e-04 - val_loss: 5.0287e-04 - val_accuracy: 0.0016
#
# Epoch 00048: val_loss did not improve from 0.00017
# Epoch 49/50
# 79/79 [==============================] - 26s 326ms/step - loss: 4.9372e-04 - accuracy: 7.9745e-04 - val_loss: 2.0342e-04 - val_accuracy: 0.0016
#
# Epoch 00049: val_loss did not improve from 0.00017
# Epoch 50/50
# 79/79 [==============================] - 24s 310ms/step - loss: 5.0031e-04 - accuracy: 7.9745e-04 - val_loss: 1.8211e-04 - val_accuracy: 0.0016
#
# Epoch 00050: val_loss did not improve from 0.00017

# %%
model.load_weights(filename)
pred = model.predict(X_test)
plt.figure(figsize=(12, 9))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.0007060613787621892, 0.9067778978388458)
