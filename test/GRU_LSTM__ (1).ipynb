# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
def Nomalizaion_datas(df):
        # 훈련시킬 데이터와, 학습후 결과를 확인할 데이터 분리
    df = df.loc[df['Date']<="2021"]
    df.sort_index(ascending=False).reset_index(drop=True)

    #정규화하기
    scaler = MinMaxScaler()
    scale_cols = ['시가', '고가', '저가', '현재가', '거래량', '거래대금', 'D', 'G',
        'O', 'Dow', 'kosdaq', 'nasdaq', 'S&P500']
    df_scaled = scaler.fit_transform(df[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    
    # 테스트사이즈, 윈도우사이즈 설정
    TEST_SIZE = 200
    WINDOW_SIZE = 20

    #--------------------------------------------------------
    train = df_scaled[:-TEST_SIZE]
    test = df_scaled[-TEST_SIZE:]

    test.reset_index(drop=True, inplace=True)
    
    return  train, test


def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(label_list)


 
def training_target(train):
    
    feature_cols = ['시가', '고가', '저가', '거래량', '거래대금', 'D', 'G',
            'O', 'kosdaq']
    label_cols = ['현재가']

    train_feature = train[feature_cols]
    train_label = train[label_cols]

    train_feature, train_label = make_dataset(train_feature, train_label, 20)

    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
    
    return x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label

  
def test_feature_label(feature_cols, label_cols):
    test_feature = test[feature_cols]
    test_label = test[label_cols]

    X_test, y_test = make_dataset(test_feature, test_label, 20)
    
    return X_test, y_test, test_feature, test_label

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM , Conv1D, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 모델 생성

# %%
df = pd.read_excel("data_kosdaq_price_OGD/에프에스티.xlsx.xlsx")
train, test= Nomalizaion_datas(df)
x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label = training_target(train)
X_test, y_test, test_feature, test_label = test_feature_label(feature_cols, label_cols)

# %%
  model = Sequential()
  model.add(GRU(units = 224, 
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 352,
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 480,  
             activation='relu', 
             return_sequences=True))
  model.add(LSTM(units = 480, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='relu',))
  optimizer_2 = Adam(0.0002)
  model.compile(loss='mean_squared_error', optimizer=optimizer_2, metrics=["accuracy"])
  early_stop = EarlyStopping(monitor='val_loss', patience=30)
# Out:
# 2022-03-25 16:39:50.218563: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_path = 'model'
filename = os.path.join(model_path, '동진쌔미캠.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train, epochs=40, batch_size=64, shuffle=False, callbacks=[early_stop, checkpoint], validation_data=(x_valid, y_valid))
    model.save('동진쌔미캠.h5')
    model.reset_states()
# Out:
# Epoch 1/40
# 48/48 [==============================] - 6s 129ms/step - loss: 5.8809e-04 - accuracy: 3.2669e-04 - val_loss: 2.4215e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.00024, saving model to model/동진쌔미캠.h5
# Epoch 2/40
# 48/48 [==============================] - 6s 130ms/step - loss: 5.2364e-04 - accuracy: 3.2669e-04 - val_loss: 2.2032e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.00024 to 0.00022, saving model to model/동진쌔미캠.h5
# Epoch 3/40
# 48/48 [==============================] - 6s 119ms/step - loss: 4.8815e-04 - accuracy: 3.2669e-04 - val_loss: 1.6834e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 0.00022 to 0.00017, saving model to model/동진쌔미캠.h5
# Epoch 4/40
# 48/48 [==============================] - 6s 123ms/step - loss: 4.4333e-04 - accuracy: 3.2669e-04 - val_loss: 3.1340e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.00017
# Epoch 5/40
# 48/48 [==============================] - 6s 120ms/step - loss: 4.5064e-04 - accuracy: 3.2669e-04 - val_loss: 1.2730e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss improved from 0.00017 to 0.00013, saving model to model/동진쌔미캠.h5
# Epoch 6/40
# 48/48 [==============================] - 6s 129ms/step - loss: 4.7407e-04 - accuracy: 3.2669e-04 - val_loss: 2.0028e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 0.00013
# Epoch 7/40
# 48/48 [==============================] - 6s 122ms/step - loss: 3.8732e-04 - accuracy: 3.2669e-04 - val_loss: 1.7783e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 0.00013
# Epoch 8/40
# 48/48 [==============================] - 6s 135ms/step - loss: 3.7490e-04 - accuracy: 3.2669e-04 - val_loss: 1.2769e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.00013
# Epoch 9/40
# 48/48 [==============================] - 6s 131ms/step - loss: 4.1209e-04 - accuracy: 3.2669e-04 - val_loss: 1.4322e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 0.00013
# Epoch 10/40
# 48/48 [==============================] - 6s 129ms/step - loss: 4.5206e-04 - accuracy: 3.2669e-04 - val_loss: 2.5904e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.00013
# Epoch 11/40
# 48/48 [==============================] - 6s 133ms/step - loss: 4.6330e-04 - accuracy: 3.2669e-04 - val_loss: 2.1911e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.00013
# Epoch 12/40
# 48/48 [==============================] - 6s 130ms/step - loss: 4.0912e-04 - accuracy: 3.2669e-04 - val_loss: 3.2174e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 0.00013
# Epoch 13/40
# 48/48 [==============================] - 6s 132ms/step - loss: 3.5872e-04 - accuracy: 3.2669e-04 - val_loss: 1.0687e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss improved from 0.00013 to 0.00011, saving model to model/동진쌔미캠.h5
# Epoch 14/40
# 48/48 [==============================] - 6s 131ms/step - loss: 3.9100e-04 - accuracy: 3.2669e-04 - val_loss: 1.0915e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.00011
# Epoch 15/40
# 48/48 [==============================] - 6s 128ms/step - loss: 3.6991e-04 - accuracy: 3.2669e-04 - val_loss: 1.8279e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.00011
# Epoch 16/40
# 48/48 [==============================] - 6s 123ms/step - loss: 3.4324e-04 - accuracy: 3.2669e-04 - val_loss: 1.3187e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.00011
# Epoch 17/40
# 48/48 [==============================] - 6s 130ms/step - loss: 3.4872e-04 - accuracy: 3.2669e-04 - val_loss: 1.6236e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.00011
# Epoch 18/40
# 48/48 [==============================] - 6s 127ms/step - loss: 4.0759e-04 - accuracy: 3.2669e-04 - val_loss: 1.1586e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.00011
# Epoch 19/40
# 48/48 [==============================] - 6s 129ms/step - loss: 3.6911e-04 - accuracy: 3.2669e-04 - val_loss: 1.6771e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.00011
# Epoch 20/40
# 48/48 [==============================] - 6s 130ms/step - loss: 3.2982e-04 - accuracy: 3.2669e-04 - val_loss: 8.8926e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00020: val_loss improved from 0.00011 to 0.00009, saving model to model/동진쌔미캠.h5
# Epoch 21/40
# 48/48 [==============================] - 6s 129ms/step - loss: 3.5032e-04 - accuracy: 3.2669e-04 - val_loss: 9.5874e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00021: val_loss did not improve from 0.00009
# Epoch 22/40
# 48/48 [==============================] - 6s 130ms/step - loss: 3.8045e-04 - accuracy: 3.2669e-04 - val_loss: 1.0556e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 0.00009
# Epoch 23/40
# 48/48 [==============================] - 6s 123ms/step - loss: 3.2424e-04 - accuracy: 3.2669e-04 - val_loss: 2.0638e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.00009
# Epoch 24/40
# 48/48 [==============================] - 6s 130ms/step - loss: 3.6328e-04 - accuracy: 3.2669e-04 - val_loss: 2.2410e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.00009
# Epoch 25/40
# 48/48 [==============================] - 6s 128ms/step - loss: 3.6453e-04 - accuracy: 3.2669e-04 - val_loss: 1.0899e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.00009
# Epoch 26/40
# 48/48 [==============================] - 6s 129ms/step - loss: 3.4533e-04 - accuracy: 3.2669e-04 - val_loss: 9.8622e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 0.00009
# Epoch 27/40
# 48/48 [==============================] - 6s 132ms/step - loss: 3.2918e-04 - accuracy: 3.2669e-04 - val_loss: 2.8624e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.00009
# Epoch 28/40
# 48/48 [==============================] - 6s 126ms/step - loss: 3.8007e-04 - accuracy: 3.2669e-04 - val_loss: 2.3677e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 0.00009
# Epoch 29/40
# 48/48 [==============================] - 6s 126ms/step - loss: 3.1106e-04 - accuracy: 3.2669e-04 - val_loss: 9.6965e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.00009
# Epoch 30/40
# 48/48 [==============================] - 6s 127ms/step - loss: 3.5163e-04 - accuracy: 3.2669e-04 - val_loss: 1.1920e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.00009
# Epoch 31/40
# 48/48 [==============================] - 6s 122ms/step - loss: 3.3306e-04 - accuracy: 3.2669e-04 - val_loss: 9.4291e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00031: val_loss did not improve from 0.00009
# Epoch 32/40
# 48/48 [==============================] - 6s 131ms/step - loss: 3.3915e-04 - accuracy: 3.2669e-04 - val_loss: 1.7828e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 0.00009
# Epoch 33/40
# 48/48 [==============================] - 7s 142ms/step - loss: 3.2926e-04 - accuracy: 3.2669e-04 - val_loss: 9.7041e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.00009
# Epoch 34/40
# 48/48 [==============================] - 6s 127ms/step - loss: 3.4632e-04 - accuracy: 3.2669e-04 - val_loss: 1.2762e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.00009
# Epoch 35/40
# 48/48 [==============================] - 6s 124ms/step - loss: 3.4082e-04 - accuracy: 3.2669e-04 - val_loss: 3.0193e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.00009
# Epoch 36/40
# 48/48 [==============================] - 6s 127ms/step - loss: 3.6129e-04 - accuracy: 3.2669e-04 - val_loss: 1.2808e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.00009
# Epoch 37/40
# 48/48 [==============================] - 6s 129ms/step - loss: 3.7454e-04 - accuracy: 3.2669e-04 - val_loss: 9.2606e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 0.00009
# Epoch 38/40
# 48/48 [==============================] - 6s 129ms/step - loss: 3.2349e-04 - accuracy: 3.2669e-04 - val_loss: 9.6607e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 0.00009
# Epoch 39/40
# 48/48 [==============================] - 6s 127ms/step - loss: 2.9826e-04 - accuracy: 3.2669e-04 - val_loss: 8.7880e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss improved from 0.00009 to 0.00009, saving model to model/동진쌔미캠.h5
# Epoch 40/40
# 48/48 [==============================] - 6s 133ms/step - loss: 3.5492e-04 - accuracy: 3.2669e-04 - val_loss: 2.7573e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 0.00009

# %%
model.load_weights(filename)
pred = model.predict(X_test)
plt.figure(figsize=(12, 9))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.006871306883662499, 0.802912142759802)
