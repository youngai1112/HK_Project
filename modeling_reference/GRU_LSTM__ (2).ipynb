# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
def Nomalizaion_datas(df):
        # 훈련시킬 데이터와, 학습후 결과를 확인할 데이터 분리
    df = df.loc[df['Date']<="2021"]
    df.sort_index(ascending=False).reset_index(drop=True)

    #정규화하기
    scaler = MinMaxScaler()
    scale_cols = ['시가', '고가', '저가', '현재가', '거래량', '거래대금', 'D', 'G',
        'O', 'Dow', 'kosdaq', 'nasdaq', 'S&P500']
    df_scaled = scaler.fit_transform(df[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    
    # 테스트사이즈, 윈도우사이즈 설정
    TEST_SIZE = 200
    WINDOW_SIZE = 20

    #--------------------------------------------------------
    train = df_scaled[:-TEST_SIZE]
    test = df_scaled[-TEST_SIZE:]

    test.reset_index(drop=True, inplace=True)
    
    return  train, test


def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(label_list)


 
def training_target(train):
    
    feature_cols = ['시가', '고가', '저가', '거래량', '거래대금', 'D', 'G',
            'O', 'kosdaq']
    label_cols = ['현재가']

    train_feature = train[feature_cols]
    train_label = train[label_cols]

    train_feature, train_label = make_dataset(train_feature, train_label, 20)

    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
    
    return x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label

  
def test_feature_label(feature_cols, label_cols):
    test_feature = test[feature_cols]
    test_label = test[label_cols]

    X_test, y_test = make_dataset(test_feature, test_label, 20)
    
    return X_test, y_test, test_feature, test_label

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM , Conv1D, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 모델 생성

# %%
df = pd.read_excel("data_kosdaq_price_OGD/유니셈.xlsx.xlsx")
train, test= Nomalizaion_datas(df)
x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label = training_target(train)
X_test, y_test, test_feature, test_label = test_feature_label(feature_cols, label_cols)

# %%
  model = Sequential()
  model.add(GRU(units = 416, 
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 384,
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 96,  
             activation='relu', 
             return_sequences=True))
  model.add(LSTM(units = 288, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='relu',))
  optimizer_2 = Adam(0.001)
  model.compile(loss='mean_squared_error', optimizer=optimizer_2, metrics=["accuracy"])
  early_stop = EarlyStopping(monitor='val_loss', patience=30)
# Out:
# 2022-03-28 10:37:49.175842: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_path = 'model'
filename = os.path.join(model_path, '유니셈.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train, epochs=50, batch_size=16, shuffle=False, callbacks=[early_stop, checkpoint], validation_data=(x_valid, y_valid))
    model.save('유니셈.h5')
    model.reset_states()
# Out:
# 2022-03-28 10:37:49.601220: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 192/192 [==============================] - 23s 104ms/step - loss: 0.0049 - accuracy: 3.2669e-04 - val_loss: 0.0024 - val_accuracy: 0.0013
#
# Epoch 00001: val_loss improved from inf to 0.00244, saving model to model/유니셈.h5
# Epoch 2/50
# 192/192 [==============================] - 19s 101ms/step - loss: 0.0017 - accuracy: 3.2669e-04 - val_loss: 7.3577e-04 - val_accuracy: 0.0013
#
# Epoch 00002: val_loss improved from 0.00244 to 0.00074, saving model to model/유니셈.h5
# Epoch 3/50
# 192/192 [==============================] - 19s 101ms/step - loss: 0.0015 - accuracy: 3.2669e-04 - val_loss: 7.5948e-04 - val_accuracy: 0.0013
#
# Epoch 00003: val_loss did not improve from 0.00074
# Epoch 4/50
# 192/192 [==============================] - 19s 101ms/step - loss: 0.0010 - accuracy: 3.2669e-04 - val_loss: 7.0683e-04 - val_accuracy: 0.0013
#
# Epoch 00004: val_loss improved from 0.00074 to 0.00071, saving model to model/유니셈.h5
# Epoch 5/50
# 192/192 [==============================] - 19s 101ms/step - loss: 9.2551e-04 - accuracy: 3.2669e-04 - val_loss: 4.1147e-04 - val_accuracy: 0.0013
#
# Epoch 00005: val_loss improved from 0.00071 to 0.00041, saving model to model/유니셈.h5
# Epoch 6/50
# 192/192 [==============================] - 19s 101ms/step - loss: 7.9665e-04 - accuracy: 3.2669e-04 - val_loss: 4.9489e-04 - val_accuracy: 0.0013
#
# Epoch 00006: val_loss did not improve from 0.00041
# Epoch 7/50
# 192/192 [==============================] - 19s 101ms/step - loss: 9.2629e-04 - accuracy: 3.2669e-04 - val_loss: 0.0012 - val_accuracy: 0.0013
#
# Epoch 00007: val_loss did not improve from 0.00041
# Epoch 8/50
# 192/192 [==============================] - 19s 101ms/step - loss: 7.4600e-04 - accuracy: 3.2669e-04 - val_loss: 3.1130e-04 - val_accuracy: 0.0013
#
# Epoch 00008: val_loss improved from 0.00041 to 0.00031, saving model to model/유니셈.h5
# Epoch 9/50
# 192/192 [==============================] - 19s 101ms/step - loss: 6.9073e-04 - accuracy: 3.2669e-04 - val_loss: 4.8024e-04 - val_accuracy: 0.0013
#
# Epoch 00009: val_loss did not improve from 0.00031
# Epoch 10/50
# 192/192 [==============================] - 19s 101ms/step - loss: 7.9283e-04 - accuracy: 3.2669e-04 - val_loss: 3.6329e-04 - val_accuracy: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00031
# Epoch 11/50
# 192/192 [==============================] - 19s 101ms/step - loss: 6.1003e-04 - accuracy: 3.2669e-04 - val_loss: 4.9389e-04 - val_accuracy: 0.0013
#
# Epoch 00011: val_loss did not improve from 0.00031
# Epoch 12/50
# 192/192 [==============================] - 19s 100ms/step - loss: 7.0849e-04 - accuracy: 3.2669e-04 - val_loss: 7.2135e-04 - val_accuracy: 0.0013
#
# Epoch 00012: val_loss did not improve from 0.00031
# Epoch 13/50
# 192/192 [==============================] - 19s 100ms/step - loss: 6.8077e-04 - accuracy: 3.2669e-04 - val_loss: 5.2249e-04 - val_accuracy: 0.0013
#
# Epoch 00013: val_loss did not improve from 0.00031
# Epoch 14/50
# 192/192 [==============================] - 19s 101ms/step - loss: 5.8142e-04 - accuracy: 3.2669e-04 - val_loss: 5.0078e-04 - val_accuracy: 0.0013
#
# Epoch 00014: val_loss did not improve from 0.00031
# Epoch 15/50
# 192/192 [==============================] - 19s 100ms/step - loss: 5.7988e-04 - accuracy: 3.2669e-04 - val_loss: 3.5954e-04 - val_accuracy: 0.0013
#
# Epoch 00015: val_loss did not improve from 0.00031
# Epoch 16/50
# 192/192 [==============================] - 19s 99ms/step - loss: 6.2780e-04 - accuracy: 3.2669e-04 - val_loss: 3.5449e-04 - val_accuracy: 0.0013
#
# Epoch 00016: val_loss did not improve from 0.00031
# Epoch 17/50
# 192/192 [==============================] - 19s 98ms/step - loss: 6.2234e-04 - accuracy: 3.2669e-04 - val_loss: 6.8614e-04 - val_accuracy: 0.0013
#
# Epoch 00017: val_loss did not improve from 0.00031
# Epoch 18/50
# 192/192 [==============================] - 19s 98ms/step - loss: 6.1717e-04 - accuracy: 3.2669e-04 - val_loss: 4.1768e-04 - val_accuracy: 0.0013
#
# Epoch 00018: val_loss did not improve from 0.00031
# Epoch 19/50
# 192/192 [==============================] - 19s 99ms/step - loss: 7.3321e-04 - accuracy: 3.2669e-04 - val_loss: 4.2980e-04 - val_accuracy: 0.0013
#
# Epoch 00019: val_loss did not improve from 0.00031
# Epoch 20/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.7594e-04 - accuracy: 3.2669e-04 - val_loss: 3.4723e-04 - val_accuracy: 0.0013
#
# Epoch 00020: val_loss did not improve from 0.00031
# Epoch 21/50
# 192/192 [==============================] - 19s 98ms/step - loss: 7.0574e-04 - accuracy: 3.2669e-04 - val_loss: 4.7949e-04 - val_accuracy: 0.0013
#
# Epoch 00021: val_loss did not improve from 0.00031
# Epoch 22/50
# 192/192 [==============================] - 19s 98ms/step - loss: 6.1621e-04 - accuracy: 3.2669e-04 - val_loss: 0.0016 - val_accuracy: 0.0013
#
# Epoch 00022: val_loss did not improve from 0.00031
# Epoch 23/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.8314e-04 - accuracy: 3.2669e-04 - val_loss: 5.6400e-04 - val_accuracy: 0.0013
#
# Epoch 00023: val_loss did not improve from 0.00031
# Epoch 24/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.8465e-04 - accuracy: 3.2669e-04 - val_loss: 2.9034e-04 - val_accuracy: 0.0013
#
# Epoch 00024: val_loss improved from 0.00031 to 0.00029, saving model to model/유니셈.h5
# Epoch 25/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.7331e-04 - accuracy: 3.2669e-04 - val_loss: 3.0459e-04 - val_accuracy: 0.0013
#
# Epoch 00025: val_loss did not improve from 0.00029
# Epoch 26/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.7089e-04 - accuracy: 3.2669e-04 - val_loss: 3.4137e-04 - val_accuracy: 0.0013
#
# Epoch 00026: val_loss did not improve from 0.00029
# Epoch 27/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.3442e-04 - accuracy: 3.2669e-04 - val_loss: 5.8531e-04 - val_accuracy: 0.0013
#
# Epoch 00027: val_loss did not improve from 0.00029
# Epoch 28/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.8968e-04 - accuracy: 3.2669e-04 - val_loss: 6.0949e-04 - val_accuracy: 0.0013
#
# Epoch 00028: val_loss did not improve from 0.00029
# Epoch 29/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.3837e-04 - accuracy: 3.2669e-04 - val_loss: 4.8353e-04 - val_accuracy: 0.0013
#
# Epoch 00029: val_loss did not improve from 0.00029
# Epoch 30/50
# 192/192 [==============================] - 19s 100ms/step - loss: 5.3237e-04 - accuracy: 3.2669e-04 - val_loss: 3.1726e-04 - val_accuracy: 0.0013
#
# Epoch 00030: val_loss did not improve from 0.00029
# Epoch 31/50
# 192/192 [==============================] - 20s 102ms/step - loss: 6.5890e-04 - accuracy: 3.2669e-04 - val_loss: 3.3798e-04 - val_accuracy: 0.0013
#
# Epoch 00031: val_loss did not improve from 0.00029
# Epoch 32/50
# 192/192 [==============================] - 19s 98ms/step - loss: 6.1350e-04 - accuracy: 3.2669e-04 - val_loss: 3.2415e-04 - val_accuracy: 0.0013
#
# Epoch 00032: val_loss did not improve from 0.00029
# Epoch 33/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.9517e-04 - accuracy: 3.2669e-04 - val_loss: 3.7434e-04 - val_accuracy: 0.0013
#
# Epoch 00033: val_loss did not improve from 0.00029
# Epoch 34/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.1381e-04 - accuracy: 3.2669e-04 - val_loss: 3.2039e-04 - val_accuracy: 0.0013
#
# Epoch 00034: val_loss did not improve from 0.00029
# Epoch 35/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.9357e-04 - accuracy: 3.2669e-04 - val_loss: 5.0744e-04 - val_accuracy: 0.0013
#
# Epoch 00035: val_loss did not improve from 0.00029
# Epoch 36/50
# 192/192 [==============================] - 19s 98ms/step - loss: 6.4296e-04 - accuracy: 3.2669e-04 - val_loss: 4.6262e-04 - val_accuracy: 0.0013
#
# Epoch 00036: val_loss did not improve from 0.00029
# Epoch 37/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.9833e-04 - accuracy: 3.2669e-04 - val_loss: 3.1885e-04 - val_accuracy: 0.0013
#
# Epoch 00037: val_loss did not improve from 0.00029
# Epoch 38/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.4700e-04 - accuracy: 3.2669e-04 - val_loss: 3.2335e-04 - val_accuracy: 0.0013
#
# Epoch 00038: val_loss did not improve from 0.00029
# Epoch 39/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.4054e-04 - accuracy: 3.2669e-04 - val_loss: 4.5978e-04 - val_accuracy: 0.0013
#
# Epoch 00039: val_loss did not improve from 0.00029
# Epoch 40/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.9794e-04 - accuracy: 3.2669e-04 - val_loss: 2.7899e-04 - val_accuracy: 0.0013
#
# Epoch 00040: val_loss improved from 0.00029 to 0.00028, saving model to model/유니셈.h5
# Epoch 41/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.3108e-04 - accuracy: 3.2669e-04 - val_loss: 5.6265e-04 - val_accuracy: 0.0013
#
# Epoch 00041: val_loss did not improve from 0.00028
# Epoch 42/50
# 192/192 [==============================] - 19s 99ms/step - loss: 4.9206e-04 - accuracy: 3.2669e-04 - val_loss: 3.2241e-04 - val_accuracy: 0.0013
#
# Epoch 00042: val_loss did not improve from 0.00028
# Epoch 43/50
# 192/192 [==============================] - 19s 98ms/step - loss: 4.8817e-04 - accuracy: 3.2669e-04 - val_loss: 3.5857e-04 - val_accuracy: 0.0013
#
# Epoch 00043: val_loss did not improve from 0.00028
# Epoch 44/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.6044e-04 - accuracy: 3.2669e-04 - val_loss: 2.8963e-04 - val_accuracy: 0.0013
#
# Epoch 00044: val_loss did not improve from 0.00028
# Epoch 45/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.7177e-04 - accuracy: 3.2669e-04 - val_loss: 4.7764e-04 - val_accuracy: 0.0013
#
# Epoch 00045: val_loss did not improve from 0.00028
# Epoch 46/50
# 192/192 [==============================] - 19s 99ms/step - loss: 4.9545e-04 - accuracy: 3.2669e-04 - val_loss: 2.7788e-04 - val_accuracy: 0.0013
#
# Epoch 00046: val_loss improved from 0.00028 to 0.00028, saving model to model/유니셈.h5
# Epoch 47/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.3604e-04 - accuracy: 3.2669e-04 - val_loss: 3.5822e-04 - val_accuracy: 0.0013
#
# Epoch 00047: val_loss did not improve from 0.00028
# Epoch 48/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.8337e-04 - accuracy: 3.2669e-04 - val_loss: 3.9436e-04 - val_accuracy: 0.0013
#
# Epoch 00048: val_loss did not improve from 0.00028
# Epoch 49/50
# 192/192 [==============================] - 19s 98ms/step - loss: 5.0206e-04 - accuracy: 3.2669e-04 - val_loss: 3.0484e-04 - val_accuracy: 0.0013
#
# Epoch 00049: val_loss did not improve from 0.00028
# Epoch 50/50
# 192/192 [==============================] - 19s 99ms/step - loss: 5.0826e-04 - accuracy: 3.2669e-04 - val_loss: 5.1666e-04 - val_accuracy: 0.0013
#
# Epoch 00050: val_loss did not improve from 0.00028

# %%
model.load_weights(filename)
pred = model.predict(X_test)
plt.figure(figsize=(12, 9))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.0005899163963307078, 0.9202420806630908)
