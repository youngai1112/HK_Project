# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
def Nomalizaion_datas(df):
        # 훈련시킬 데이터와, 학습후 결과를 확인할 데이터 분리
    df = df.loc[df['Date']<="2021"]
    df.sort_index(ascending=False).reset_index(drop=True)

    #정규화하기
    scaler = MinMaxScaler()
    scale_cols = ['시가', '고가', '저가', '현재가', '거래량', '거래대금', 'D', 'G',
        'O', 'Dow', 'kosdaq', 'nasdaq', 'S&P500']
    df_scaled = scaler.fit_transform(df[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    
    # 테스트사이즈, 윈도우사이즈 설정
    TEST_SIZE = 200
    WINDOW_SIZE = 20

    #--------------------------------------------------------
    train = df_scaled[:-TEST_SIZE]
    test = df_scaled[-TEST_SIZE:]

    test.reset_index(drop=True, inplace=True)
    
    return  train, test


def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    
    return np.array(feature_list), np.array(label_list)


 
def training_target(train):
    
    feature_cols = ['시가', '고가', '저가', '거래량', '거래대금', 'D', 'G',
            'O', 'kosdaq']
    label_cols = ['현재가']

    train_feature = train[feature_cols]
    train_label = train[label_cols]

    train_feature, train_label = make_dataset(train_feature, train_label, 20)

    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
    
    return x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label

  
def test_feature_label(feature_cols, label_cols):
    test_feature = test[feature_cols]
    test_label = test[label_cols]

    X_test, y_test = make_dataset(test_feature, test_label, 20)
    
    return X_test, y_test, test_feature, test_label

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM , Conv1D, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 모델 생성

# %%
df = pd.read_excel("data_kosdaq_price_OGD/동진썌미캠.xlsx.xlsx")
train, test= Nomalizaion_datas(df)
x_train, x_valid, y_train, y_valid, feature_cols, label_cols, train_feature, train_label = training_target(train)
X_test, y_test, test_feature, test_label = test_feature_label(feature_cols, label_cols)

# %%
  model = Sequential()
  model.add(GRU(units = 288, 
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 128,
             input_shape=(train_feature.shape[1], train_feature.shape[2]), 
             activation='relu', 
             return_sequences=True))
  model.add(GRU(units = 96,  
             activation='relu', 
             return_sequences=True))
  model.add(LSTM(units = 64, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(1,activation='relu',))
  optimizer_2 = Adam(0.004)
  model.compile(loss='mean_squared_error', optimizer=optimizer_2, metrics=["accuracy"])
  early_stop = EarlyStopping(monitor='val_loss', patience=30)

# %%
model_path = 'model'
filename = os.path.join(model_path, '동진쌔미캠.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train, epochs=40, batch_size=64, shuffle=False, callbacks=[early_stop, checkpoint], validation_data=(x_valid, y_valid))
    model.save('동진썌미캼.h5')
    model.reset_states()
# Out:
# Epoch 1/40
# 42/42 [==============================] - 21s 353ms/step - loss: 0.0069 - accuracy: 3.7679e-04 - val_loss: 5.8532e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.00059, saving model to model/GST.h5
# Epoch 2/40
# 42/42 [==============================] - 13s 309ms/step - loss: 6.0704e-04 - accuracy: 3.7679e-04 - val_loss: 3.7267e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.00059 to 0.00037, saving model to model/GST.h5
# Epoch 3/40
# 42/42 [==============================] - 12s 293ms/step - loss: 4.3519e-04 - accuracy: 3.7679e-04 - val_loss: 3.0506e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 0.00037 to 0.00031, saving model to model/GST.h5
# Epoch 4/40
# 42/42 [==============================] - 13s 323ms/step - loss: 4.4986e-04 - accuracy: 3.7679e-04 - val_loss: 3.3105e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.00031
# Epoch 5/40
# 42/42 [==============================] - 13s 301ms/step - loss: 4.1536e-04 - accuracy: 3.7679e-04 - val_loss: 2.6145e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss improved from 0.00031 to 0.00026, saving model to model/GST.h5
# Epoch 6/40
# 42/42 [==============================] - 13s 301ms/step - loss: 3.5679e-04 - accuracy: 3.7679e-04 - val_loss: 2.4881e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss improved from 0.00026 to 0.00025, saving model to model/GST.h5
# Epoch 7/40
# 42/42 [==============================] - 12s 278ms/step - loss: 3.3217e-04 - accuracy: 3.7679e-04 - val_loss: 2.2197e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss improved from 0.00025 to 0.00022, saving model to model/GST.h5
# Epoch 8/40
# 42/42 [==============================] - 11s 270ms/step - loss: 3.2695e-04 - accuracy: 3.7679e-04 - val_loss: 2.2745e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.00022
# Epoch 9/40
# 42/42 [==============================] - 15s 368ms/step - loss: 3.6663e-04 - accuracy: 3.7679e-04 - val_loss: 1.8030e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss improved from 0.00022 to 0.00018, saving model to model/GST.h5
# Epoch 10/40
# 42/42 [==============================] - 12s 276ms/step - loss: 3.4401e-04 - accuracy: 3.7679e-04 - val_loss: 2.9175e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.00018
# Epoch 11/40
# 42/42 [==============================] - 11s 270ms/step - loss: 3.0665e-04 - accuracy: 3.7679e-04 - val_loss: 1.4822e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss improved from 0.00018 to 0.00015, saving model to model/GST.h5
# Epoch 12/40
# 42/42 [==============================] - 11s 270ms/step - loss: 3.3331e-04 - accuracy: 3.7679e-04 - val_loss: 2.5296e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00012: val_loss did not improve from 0.00015
# Epoch 13/40
# 42/42 [==============================] - 11s 272ms/step - loss: 2.9289e-04 - accuracy: 3.7679e-04 - val_loss: 2.2179e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.00015
# Epoch 14/40
# 42/42 [==============================] - 12s 278ms/step - loss: 2.7630e-04 - accuracy: 3.7679e-04 - val_loss: 1.8409e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.00015
# Epoch 15/40
# 42/42 [==============================] - 11s 271ms/step - loss: 2.9480e-04 - accuracy: 3.7679e-04 - val_loss: 1.9120e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.00015
# Epoch 16/40
# 42/42 [==============================] - 12s 275ms/step - loss: 3.0796e-04 - accuracy: 3.7679e-04 - val_loss: 1.3112e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00016: val_loss improved from 0.00015 to 0.00013, saving model to model/GST.h5
# Epoch 17/40
# 42/42 [==============================] - 12s 273ms/step - loss: 2.2653e-04 - accuracy: 3.7679e-04 - val_loss: 1.2360e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00017: val_loss improved from 0.00013 to 0.00012, saving model to model/GST.h5
# Epoch 18/40
# 42/42 [==============================] - 12s 274ms/step - loss: 2.2425e-04 - accuracy: 3.7679e-04 - val_loss: 1.5017e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.00012
# Epoch 19/40
# 42/42 [==============================] - 10s 249ms/step - loss: 3.0981e-04 - accuracy: 3.7679e-04 - val_loss: 1.8407e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.00012
# Epoch 20/40
# 42/42 [==============================] - 10s 247ms/step - loss: 2.7185e-04 - accuracy: 3.7679e-04 - val_loss: 1.3967e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.00012
# Epoch 21/40
# 42/42 [==============================] - 11s 252ms/step - loss: 2.3444e-04 - accuracy: 3.7679e-04 - val_loss: 1.0981e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00021: val_loss improved from 0.00012 to 0.00011, saving model to model/GST.h5
# Epoch 22/40
# 42/42 [==============================] - 11s 272ms/step - loss: 2.2484e-04 - accuracy: 3.7679e-04 - val_loss: 1.4694e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00022: val_loss did not improve from 0.00011
# Epoch 23/40
# 42/42 [==============================] - 12s 274ms/step - loss: 2.2601e-04 - accuracy: 3.7679e-04 - val_loss: 1.1105e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00023: val_loss did not improve from 0.00011
# Epoch 24/40
# 42/42 [==============================] - 11s 270ms/step - loss: 2.1513e-04 - accuracy: 3.7679e-04 - val_loss: 1.2159e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00024: val_loss did not improve from 0.00011
# Epoch 25/40
# 42/42 [==============================] - 12s 277ms/step - loss: 2.0975e-04 - accuracy: 3.7679e-04 - val_loss: 1.2671e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 0.00011
# Epoch 26/40
# 42/42 [==============================] - 12s 277ms/step - loss: 2.3008e-04 - accuracy: 3.7679e-04 - val_loss: 1.1411e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 0.00011
# Epoch 27/40
# 42/42 [==============================] - 12s 275ms/step - loss: 2.1249e-04 - accuracy: 3.7679e-04 - val_loss: 2.1629e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 0.00011
# Epoch 28/40
# 42/42 [==============================] - 12s 276ms/step - loss: 2.3035e-04 - accuracy: 3.7679e-04 - val_loss: 1.4000e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 0.00011
# Epoch 29/40
# 42/42 [==============================] - 12s 279ms/step - loss: 2.1815e-04 - accuracy: 3.7679e-04 - val_loss: 1.2565e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00029: val_loss did not improve from 0.00011
# Epoch 30/40
# 42/42 [==============================] - 12s 281ms/step - loss: 2.1374e-04 - accuracy: 3.7679e-04 - val_loss: 1.6889e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00030: val_loss did not improve from 0.00011
# Epoch 31/40
# 42/42 [==============================] - 12s 275ms/step - loss: 2.0619e-04 - accuracy: 3.7679e-04 - val_loss: 9.8124e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00031: val_loss improved from 0.00011 to 0.00010, saving model to model/GST.h5
# Epoch 32/40
# 42/42 [==============================] - 11s 270ms/step - loss: 1.9273e-04 - accuracy: 3.7679e-04 - val_loss: 1.0896e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00032: val_loss did not improve from 0.00010
# Epoch 33/40
# 42/42 [==============================] - 12s 275ms/step - loss: 1.9068e-04 - accuracy: 3.7679e-04 - val_loss: 1.0937e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00033: val_loss did not improve from 0.00010
# Epoch 34/40
# 42/42 [==============================] - 12s 278ms/step - loss: 2.1565e-04 - accuracy: 3.7679e-04 - val_loss: 1.5658e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00034: val_loss did not improve from 0.00010
# Epoch 35/40
# 42/42 [==============================] - 11s 269ms/step - loss: 1.9260e-04 - accuracy: 3.7679e-04 - val_loss: 9.8914e-05 - val_accuracy: 0.0000e+00
#
# Epoch 00035: val_loss did not improve from 0.00010
# Epoch 36/40
# 42/42 [==============================] - 12s 274ms/step - loss: 2.0992e-04 - accuracy: 3.7679e-04 - val_loss: 1.1801e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 0.00010
# Epoch 37/40
# 42/42 [==============================] - 12s 275ms/step - loss: 1.8563e-04 - accuracy: 3.7679e-04 - val_loss: 1.1201e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 0.00010
# Epoch 38/40
# 42/42 [==============================] - 12s 278ms/step - loss: 1.9568e-04 - accuracy: 3.7679e-04 - val_loss: 1.3103e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 0.00010
# Epoch 39/40
# 42/42 [==============================] - 12s 275ms/step - loss: 2.1728e-04 - accuracy: 3.7679e-04 - val_loss: 2.3742e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00039: val_loss did not improve from 0.00010
# Epoch 40/40
# 42/42 [==============================] - 12s 275ms/step - loss: 2.2338e-04 - accuracy: 3.7679e-04 - val_loss: 1.2223e-04 - val_accuracy: 0.0000e+00
#
# Epoch 00040: val_loss did not improve from 0.00010

# %%
model.load_weights(filename)
pred = model.predict(X_test)
plt.figure(figsize=(12, 9))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mean_squared_error(y_test, pred), r2_score(y_test, pred)
# Out:
# (0.0013452971007591305, 0.8788300432825138)
