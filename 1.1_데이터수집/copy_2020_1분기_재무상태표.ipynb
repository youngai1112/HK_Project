# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('2020_1분기보고서_01_재무상태표_연결_20211104.txt', sep = '\t', encoding='euc-kr')
column_names = ['종목코드', '회사명', '업종', '업종명', '항목명', '당기 1분기말']
df = df[column_names]
df.head()
# Out:
#        종목코드 회사명   업종            업종명                항목명         당기 1분기말
# 0  [060310]  3S  292  특수 목적용 기계 제조업      자산 [abstract]             NaN
# 1  [060310]  3S  292  특수 목적용 기계 제조업               유동자산  15,466,570,449
# 2  [060310]  3S  292  특수 목적용 기계 제조업           현금및현금성자산   4,973,422,676
# 3  [060310]  3S  292  특수 목적용 기계 제조업             단기금융상품      61,396,650
# 4  [060310]  3S  292  특수 목적용 기계 제조업        매출채권 및 기타채권   3,311,932,854

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80829 entries, 0 to 80828
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종목코드     80829 non-null  object
#  1   회사명      80829 non-null  object
#  2   업종       80829 non-null  int64
#  3   업종명      80829 non-null  object
#  4   항목명      80829 non-null  object
#  5   당기 1분기말  74495 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 3.7+ MB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74495 entries, 1 to 80828
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종목코드     74495 non-null  object
#  1   회사명      74495 non-null  object
#  2   업종       74495 non-null  int64
#  3   업종명      74495 non-null  object
#  4   항목명      74495 non-null  object
#  5   당기 1분기말  74495 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 4.0+ MB

# %%
df['종목코드'] = df['종목코드'].apply(lambda x : x.replace('[', ''))
df['종목코드'] = df['종목코드'].apply(lambda x : str(x.replace(']', '')))
df['항목명'] = df['항목명'].apply(lambda x : x.strip())
df['항목명'] = df['항목명'].str.replace('[^가-힣 ]', '')
df['항목명'] = df['항목명'].str.replace('이익잉여금결손금', '이익잉여금')
df['항목명'] = df['항목명'].str.replace('당기말', '자본총계')
df['당기 1분기말'] = df['당기 1분기말'].apply(lambda x : int(x.replace(',', '')))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74495 entries, 1 to 80828
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종목코드     74495 non-null  object
#  1   회사명      74495 non-null  object
#  2   업종       74495 non-null  int64
#  3   업종명      74495 non-null  object
#  4   항목명      74495 non-null  object
#  5   당기 1분기말  74495 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 4.0+ MB

# %%
df['항목명'] = df['항목명'].str.replace('결손금', '이익잉여금')

# %%
df.head(50)
# Out:
#       종목코드     회사명   업종              업종명                  항목명       당기 1분기말
# 1   060310      3S  292    특수 목적용 기계 제조업                 유동자산   15466570449
# 2   060310      3S  292    특수 목적용 기계 제조업             현금및현금성자산    4973422676
# 3   060310      3S  292    특수 목적용 기계 제조업               단기금융상품      61396650
# 4   060310      3S  292    특수 목적용 기계 제조업          매출채권 및 기타채권    3311932854
# 5   060310      3S  292    특수 목적용 기계 제조업                 재고자산    3078852402
# 6   060310      3S  292    특수 목적용 기계 제조업               선급공사원가    3634869221
# 7   060310      3S  292    특수 목적용 기계 제조업              당기법인세자산      12931226
# 8   060310      3S  292    특수 목적용 기계 제조업               기타유동자산     393165420
# 9   060310      3S  292    특수 목적용 기계 제조업            매각예정비유동자산             0
# 10  060310      3S  292    특수 목적용 기계 제조업                비유동자산   33376189495
# 11  060310      3S  292    특수 목적용 기계 제조업         장기성매출채권및기타채권     408014149
# 12  060310      3S  292    특수 목적용 기계 제조업               장기금융상품     968231621
# 13  060310      3S  292    특수 목적용 기계 제조업          비유동매도가능금융자산    1077852890
# 14  060310      3S  292    특수 목적용 기계 제조업        당기손익공정가치 금융자산     647539505
# 15  060310      3S  292    특수 목적용 기계 제조업        관계기업에 대한 투자자산   27361847998
# 16  060310      3S  292    특수 목적용 기계 제조업                 유형자산     442723280
# 17  060310      3S  292    특수 목적용 기계 제조업                투자부동산    1385780885
# 18  060310      3S  292    특수 목적용 기계 제조업                 무형자산    1076019349
# 19  060310      3S  292    특수 목적용 기계 제조업              기타비유동자산       8179818
# 20  060310      3S  292    특수 목적용 기계 제조업                 자산총계   48842759944
# 22  060310      3S  292    특수 목적용 기계 제조업                 유동부채   13257480000
# 23  060310      3S  292    특수 목적용 기계 제조업          매입채무 및 기타채무    1548895095
# 24  060310      3S  292    특수 목적용 기계 제조업              당기법인세부채             0
# 25  060310      3S  292    특수 목적용 기계 제조업                단기차입금    7489000000
# 26  060310      3S  292    특수 목적용 기계 제조업              유동성장기부채             0
# 27  060310      3S  292    특수 목적용 기계 제조업                 전환사채    1641041041
# 28  060310      3S  292    특수 목적용 기계 제조업                 리스부채     259902631
# 29  060310      3S  292    특수 목적용 기계 제조업             하자보수충당부채     359823966
# 30  060310      3S  292    특수 목적용 기계 제조업               기타유동부채    1958817267
# 31  060310      3S  292    특수 목적용 기계 제조업                비유동부채    2702024632
# 32  060310      3S  292    특수 목적용 기계 제조업                장기차입금    2500000000
# 33  060310      3S  292    특수 목적용 기계 제조업                 리스부채     193853662
# 34  060310      3S  292    특수 목적용 기계 제조업               기타금융부채       8170970
# 35  060310      3S  292    특수 목적용 기계 제조업                 부채총계   15959504632
# 37  060310      3S  292    특수 목적용 기계 제조업  지배기업의 소유주에게 귀속되는 자본   32883255312
# 38  060310      3S  292    특수 목적용 기계 제조업                  자본금   22401255500
# 39  060310      3S  292    특수 목적용 기계 제조업               기타불입자본   43712391560
# 40  060310      3S  292    특수 목적용 기계 제조업                이익잉여금  -33225955778
# 41  060310      3S  292    특수 목적용 기계 제조업             기타자본구성요소      -4435970
# 42  060310      3S  292    특수 목적용 기계 제조업                비지배지분             0
# 43  060310      3S  292    특수 목적용 기계 제조업                 자본총계   32883255312
# 44  060310      3S  292    특수 목적용 기계 제조업              자본과부채총계   48842759944
# 46  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업                 유동자산  446681157761
# 47  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업             현금및현금성자산  137147408446
# 48  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업                 매출채권  100189322424
# 49  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업                 재고자산   65994113818
# 50  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업      당기손익공정가치측정 금융자산   66480076325
# 51  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업             기타유동금융자산   49720795555
# 52  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업               기타유동자산   27149441193
# 53  095570  AJ네트웍스  763  산업용 기계 및 장비 임대업            매각예정비유동자산   17631592177

# %%
df = df[df['항목명'].isin(['유동자산', '재고자산', '자산총계', '유동부채', '부채총계', '자본금', '이익잉여금', '자본총계'])]

# %%
df.shape
# Out:
# (13384, 6)

# %%
df['종목코드'].nunique()
# Out:
# 1701

# %%
df.head()
# Out:
#       종목코드 회사명   업종            업종명   항목명      당기 1분기말
# 1   060310  3S  292  특수 목적용 기계 제조업  유동자산  15466570449
# 5   060310  3S  292  특수 목적용 기계 제조업  재고자산   3078852402
# 20  060310  3S  292  특수 목적용 기계 제조업  자산총계  48842759944
# 22  060310  3S  292  특수 목적용 기계 제조업  유동부채  13257480000
# 35  060310  3S  292  특수 목적용 기계 제조업  부채총계  15959504632

# %%
df.to_excel('2020_1분기보고서_01_재무상태표_연결.xlsx')
