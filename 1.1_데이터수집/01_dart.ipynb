# %%
import pandas as pd

# %%
df = pd.read_csv('../data/2020_3분기보고서_01_재무상태표_20211102.txt', sep='\t', encoding='euc-kr')
df.head()
# Out:
#                   재무제표종류      종목코드 회사명       시장구분   업종            업종명  결산월  \
# 0  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 1  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 2  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 3  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 4  재무상태표, 유동/비유동법-별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
#
#         결산기준일   보고서종류   통화                                               항목코드  \
# 0  2020-12-31  3분기보고서  KRW                           ifrs-full_AssetsAbstract
# 1  2020-12-31  3분기보고서  KRW                            ifrs-full_CurrentAssets
# 2  2020-12-31  3분기보고서  KRW                   ifrs-full_CashAndCashEquivalents
# 3  2020-12-31  3분기보고서  KRW  dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 4  2020-12-31  3분기보고서  KRW          ifrs-full_TradeAndOtherCurrentReceivables
#
# ...

# %%
df.isna().sum()
# Out:
# 재무제표종류             0
# 종목코드               0
# 회사명                0
# 시장구분               0
# 업종                 0
# 업종명                0
# 결산월                0
# 결산기준일              0
# 보고서종류              0
# 통화                 0
# 항목코드               0
# 항목명                0
# 당기 3분기말         7901
# 전기말             8412
# 전전기말           90751
# Unnamed: 15    90751
# dtype: int64
